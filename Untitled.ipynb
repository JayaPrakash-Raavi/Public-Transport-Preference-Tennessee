# %%
import pandas as pd

# %%
data=pd.read_csv("transport_data.csv")

# %%
data.head()
# Out:
#          StartDate          EndDate      Status      IPAddress Progress  \
# 0  7/12/2023 19:16  7/12/2023 19:22  IP Address   73.113.59.42      100
# 1   7/12/2023 9:30   7/12/2023 9:36  IP Address  69.137.73.140      100
# 2   7/14/2023 8:16   7/14/2023 8:22  IP Address    96.32.234.6      100
# 3   7/15/2023 6:04   7/15/2023 6:10  IP Address  107.77.237.54      100
# 4   7/15/2023 8:37   7/15/2023 8:43  IP Address  64.82.156.176      100
#
#   Duration (in seconds) Finished     RecordedDate         ResponseId  \
# 0                   361     TRUE  7/12/2023 19:22  R_1LhatS1gaEeEArT
# 1                   362     TRUE   7/12/2023 9:37  R_1pYAWKb2EcGJWKF
# 2                   362     TRUE   7/14/2023 8:22  R_11bYAek21nTiqeQ
# 3                   362     TRUE   7/15/2023 6:10  R_3eldD5XDXim2ZyP
# 4                   362     TRUE   7/15/2023 8:43  R_UVMKQ9XpImM1AGd
#
#   RecipientLastName  ... verification  \
# 0               NaN  ...      success
# ...
